# %% [markdown]
# # PV Diagnosis
#
# In case of large-scale renewable energy plants, production output is regularly reviewed to ensure ROI. This is different for small plants. By comparing meteorological data with actual production of a PV power plant, we estimate plant's condition and predict next required maintenance. The analysis detects performance losses and, therby, enhances economic profits. This challenge was part of the Energy Hackdays 2019 (https://hack.opendata.ch/project/284).

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data Preparation</a></span></li><li><span><a href="#Descriptive-Statistics" data-toc-modified-id="Descriptive-Statistics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Descriptive Statistics</a></span><ul class="toc-item"><li><span><a href="#Power-Generation" data-toc-modified-id="Power-Generation-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Power Generation</a></span></li><li><span><a href="#Weather-Data" data-toc-modified-id="Weather-Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Weather Data</a></span><ul class="toc-item"><li><span><a href="#Distribution-Plots" data-toc-modified-id="Distribution-Plots-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Distribution Plots</a></span></li></ul></li></ul></li><li><span><a href="#Correlation-Analysis" data-toc-modified-id="Correlation-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Correlation Analysis</a></span></li><li><span><a href="#Descriptive-Analysis" data-toc-modified-id="Descriptive-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Descriptive Analysis</a></span><ul class="toc-item"><li><span><a href="#Scatterplots:-dependend-variable-against-independent-variables" data-toc-modified-id="Scatterplots:-dependend-variable-against-independent-variables-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Scatterplots: dependend variable against independent variables</a></span></li></ul></li><li><span><a href="#Time-Series-Analysis" data-toc-modified-id="Time-Series-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Time Series Analysis</a></span></li><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Linear Regression</a></span></li></ul></div>

# %% [markdown]
# ## Data Preparation

# %%
import sys,os
os.chdir("..")
sys.path.append(os.getcwd())

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %pwd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
import seaborn as sns; sns.set("notebook")
import altair as alt
alt.data_transformers.disable_max_rows()
import ppscore as pps
from preprocessor.paths import (PATH_TO_PLANT_A,
                                 PATH_TO_PLANT_B,
                                 PATH_TO_PLANT_C,
                                 PATH_TO_WEATHER)
from preprocessor.preprocessor import Preprocessor

# %%
data_plant_a = Preprocessor(path_to_data=PATH_TO_PLANT_A, 
                            local_time_column="timestamp", 
                            resampling_method="sum").df_indexed_utc
pv_generation_kw = data_plant_a["generation_kw"]

data_weather = Preprocessor(path_to_data=PATH_TO_WEATHER, 
                            local_time_column="local_time",
                            resampling_method="mean").df_indexed_utc

df = pd.merge(left=pv_generation_kw, right=data_weather,
                left_index=True, right_index=True)

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Power Generation

# %%
fig, axes = plt.subplots(nrows=2, figsize=(20,10))
plt.subplots_adjust(hspace=0.5)

pv_generation_kw.plot(ax=axes[0])
axes[0].set_title("Power Generation in kW per hour")
axes[0].set_xlabel("")

pv_generation_kw.plot(kind="hist", 
                      bins = 30,
                      range = (0.0001,
                               max(pv_generation_kw)),
                      ax=axes[1])
axes[1].set_title("Distribution of Power Generation in kW")

plt.show()

# %% [markdown]
# ### Weather Data

# %%
data_weather.columns
# Out:
# Index(['time', 'local_time', 'temperature', 'precipitation', 'snowfall',
#        'snow_mass', 'air_density', 'radiation_surface', 'radiation_toa',
#        'cloud_cover', 'timestamp_utc', 'hour', 'week'],
#       dtype='object')

# %%
fig, axes = plt.subplots(ncols=2, nrows=4, figsize=(20,10), sharex=True)
plt.subplots_adjust(hspace=0.5)

variables = ['temperature', 'precipitation', 'snowfall', 'snow_mass', 
             'air_density', 'radiation_surface', 'radiation_toa', 'cloud_cover']
for i in range(len(variables)):
    var = variables[i]
    data_weather[var].plot(ax=axes[i%4][i//4],
                           title=str(var))
plt.show()

# %% [markdown]
# #### Distribution Plots

# %%
fig, axes = plt.subplots(ncols=2, nrows=4, figsize=(20,10))
plt.subplots_adjust(hspace=0.7)

for i in range(len(variables)):
    var = variables[i]
    sns.distplot(data_weather[var],
                 ax=axes[i%4][i//4])
    axes[i%4][i//4].set_title(var)
    axes[i%4][i//4].set_xlabel("")
plt.suptitle("Distribution Plots")
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# In the following matrix you will see which features correlate with each other.
# A dark green indicates a strong positive correlation and a dark brown a strong negative one.

# %%
def corr_heatmap(df):
    fig, ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(df, vmin=-1, vmax=1, cmap="BrBG", linewidths=0.5, annot=True)
    ax.set_title('Correlation matrix')
    return plt.show()

# %%
sns.set("notebook")
corr_heatmap(df.corr())

# %% [markdown]
# **Findings**
# - *generation_kw* is highly correlated with *radiation_surface* and *radiation_toa*, and these are highly correlated with each other --> multicollinearity
# - *air_density* and *temperature* are highly negatively correlated --> multicollinearity
# - Candidates for predictors: ***radiation_surface*, *precipitation*, *temperature***

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# Since *generation_kw* is strongly left skewed (many zero and close to zero values), the variable is transformed by taking the logarithm

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,5))
plot = sns.distplot(df["generation_kw"], ax=axes[0])
plot.set_title("generation_kw")

plot_log = sns.distplot(np.log(df["generation_kw"]+0.001), ax=axes[1])
plot_log.set_title("log generation_kw")

plt.show()

# %% [markdown]
# ### Scatterplots: dependend variable against independent variables

# %%
indep_vars = ['radiation_surface', 'precipitation', "temperature"]
X = df[predictors]
dep_vars = "generation_kw"
y = df[dependend_variable]

# %%
for i in range(len(X.columns)):
    x = X.iloc[:,i]
    x_name = indep_vars[i]
    g = sns.jointplot(data=df, y=y, x=x, 
                      kind='reg', 
                      joint_kws={'line_kws':{'color':'red'},
                                 "order":3, "fit_reg":True})
    plt.show()

# %% [markdown]
# <!-- **Note:** $log(y) = \alpha_0 + \alpha_1 log(x) + \epsilon$ -->
# - These scatterplots indicate an increase in *generation_kw* by an increase in *radiation_surface* and *temperature* as well as
# - an increase in *generation_kw* by a decrease in *precipation*

# %% [markdown]
# ## Time Series Analysis

# %%
y = y.resample("h").mean().ffill().asfreq("h")
decomp = seasonal_decompose(y, model='additive')

fig, axes = plt.subplots(nrows=4, figsize=(20,15))
decomp.observed.plot(ax=axes[0], 
                     title="observed data")
decomp.trend.plot(ax=axes[1], 
                  title="Trend")
decomp.seasonal[0:(24*7)].plot(ax=axes[2], 
                           
                               title="Seasonal Component")
decomp.resid.plot(ax=axes[3], 
                  title="Random Component")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# features = "radiation_surface"
# target = "generation_kw"


# X_train = df_train[features]
# y_train = df_train[target]

# X_test = df_test[features]
# y_test = df_test[target]

# regressor_OLS=sm.OLS(endog = y_train, exog = X_train).fit()
# regressor_OLS.summary()
import statsmodels.formula.api as smf
mod = smf.ols(formula='generation_kw ~ radiation_surface + radiation_surface**temperature', data=df)
res = mod.fit()
res.summary()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-66-278f0fda9aed> in <module>
#      12 # regressor_OLS.summary()
#      13 import statsmodels.formula.api as smf
# ---> 14 mod = smf.ols(formula='generation_kw ~ radiation_surface + radiation_surface**temperature', data=df)
#      15 res = mod.fit()
#      16 res.summary()
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     167
#     168         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 169                                   missing=missing)
#     170         ((endog, exog), missing_idx, design_info) = tmp
#     171         max_endog = cls._formula_max_endog
#
# ~\anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
# ...

# %%
# y: residual = predicted - estimated
# x: time
# residual analysis with python
